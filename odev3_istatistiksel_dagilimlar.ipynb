# %% [markdown]
# ### dağılım = np.random.dağılım_adı([],[]) kodunu kullanarak, dağılım_adı yazan yere seçtiğiniz bir dağılımı ve parantez içinde [] şeklinde gösterilen boşlukları yine kendi seçiminiz doğrultusunda doldurun. Daha sonra, a) Verinin histogramını çiziniz b) Q-Q grafiğini çizip yorumlayınız

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import norm
import seaborn as sns
from scipy import stats

dolar_kuru_veri=[5.69,5.69,5.76,5.47,5.42,5.48,5.47,5.45,5.45,5.47,5.46,5.46,5.45,5.43,5.43,5.47,5.43,5.39,5.38,5.37,5.37,
                 5.34,5.31,5.31,5.30]

normal_dagilimli_veri=np.random.normal(np.mean(dolar_kuru_veri),
                                      np.std(dolar_kuru_veri),25)

dolar_kuru_veri.sort()
normal_dagilimli_veri.sort()
plt.figure(figsize=(8,6) , dpi=100)
baslik_font = {'family': 'calibri', 'color': 'darkred','weight': 'bold','size': 12 }
eksen_font  = {'family': 'calibri', 'color': 'darkred','weight': 'bold','size': 12}
plt.title('Dolar Kuru Veri Kümesi & Normal Dağılımlı Veri Kümesi', fontdict = baslik_font)
plt.xlabel('Dolar Kuru Veri Kümesi', fontdict = eksen_font)
plt.ylabel('Normal Dağılımlı Veri Kümesi', fontdict = eksen_font)
plt.scatter(normal_dagilimli_veri, dolar_kuru_veri)
plt.plot([np.min(normal_dagilimli_veri), np.max(normal_dagilimli_veri)],
         [np.min(dolar_kuru_veri), np.max(dolar_kuru_veri)], c='red')
plt.show()

plt.figure(figsize=(10,4), dpi = 100)
nsample = 100
res = stats.probplot(dolar_kuru_veri, plot=plt)
plt.title("Q-Q Çizgesi", fontdict = baslik_font)
plt.xlabel("Teorik Değerler", fontdict = eksen_font)
plt.ylabel("Dolar kuru veri", fontdict = eksen_font)
plt.show()

plt.figure(figsize=(8,4), dpi = 100)
plt.hist(dolar_kuru_veri, bins=20, color = 'c')
plt.axvline(np.mean(dolar_kuru_veri), color='b', linestyle='solid', linewidth=2)
plt.axvline(np.mean(dolar_kuru_veri) + np.std(dolar_kuru_veri), 
            color='b', linestyle='dashed', linewidth=2)
plt.axvline(np.mean(dolar_kuru_veri) - np.std(dolar_kuru_veri), 
            color='b', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ### https://finance.yahoo.com/ sitesini kullanarak google şirketinin 2015-2017 yılları arasında hisse senedi fiyatlarını elde edin.Getiriler dağılımı hangi dağılıma daha yakındır?

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("google.csv")
a=df["Close"]

print("Hisse Senedi Getirileri ")
my=[]
x=0
i=1
while x<len(a)-1:
    PT=a[i-1]
    Pt=a[i]
    A=(PT-Pt)/Pt
    my.append(A)
    print(A)
    i+=1
    x+=1

normal_dagilimli_veri = np.random.normal(np.mean(my),
                                         np.std(my), 755)
my.sort()
normal_dagilimli_veri.sort()

plt.figure(figsize=(8,5), dpi = 100)
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.title('my & Normal Dağılımlı Veri Kümesi', fontdict = baslik_font)
plt.xlabel('my', fontdict = eksen_font)
plt.ylabel('Normal Dağılımlı Veri Kümesi', fontdict = eksen_font)
plt.scatter(normal_dagilimli_veri, my)
plt.plot([np.min(normal_dagilimli_veri), np.max(normal_dagilimli_veri)],
         [np.min(my), np.max(my)], c='red')
plt.show()
# Out:
# Hisse Senedi Getirileri
# 0.003034229691577854
# 0.02128943320298868
# 0.023726991823380665
# 0.0017162097042571025
# -0.0031431491821204247
# 0.013120492418735471
# 0.007349509709018518
# -0.007315902942851625
# -0.009363717074418342
# -0.0018334024481847175
# -0.012379957387474473
# 0.002327897294945481
# -0.021504090374566538
# -0.030595709674624542
# -0.010297195146591479
# 0.008856321318192676
# 0.03196883997123928
# 0.016921559687210548
# -0.0012924748433838591
# -0.04463815061599082
# 0.011429031952550983
# -0.0014360583751554527
# 0.012395713708132115
# -0.009135976590146738
# -0.006440722341879142
# 0.006005718091604101
# -0.016966474183567705
# 0.0018097459941790238
# -0.01281927086859742
# -0.011074531491277927
# 0.011366144547489309
# 0.00581802451887333
# -0.005843714332485822
# 0.007277868164739259
# 0.013235311050296593
# -0.007797164344426426
# -0.014304900980374863
# -0.020900820918287176
# -0.005229287343272329
# -0.022648442263755467
# -0.0040094864914471595
# ...
