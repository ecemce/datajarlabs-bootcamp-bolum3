# %% [markdown]
# ### İki madeni paramızın olduğunu varsayalım. Bunlardan bir tanesi adil (yani, yeteri kadar deneme yapıldığında yazı veya tura 1/2 olasılığına yaklaşmakta) diğeri ile ise 3/4 olasılığında tura elde edilmektedir.Herhangi biri seçilip, n kere deneme yapıldığında,Sn tura sayısı olursa, Büyük Sayılar Yasası uzun vadede gelecek tura sayısını tahmin etmemize izin verir mi? Çok sayıda deneme yapıldığında, hangi paranın seçildiğini bilebilir miyiz? Kaç deneme bizi %95 oranında emin kılar?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

np.random.seed(42)
n=10
p1=0.5
p2=0.75
size=100

normal_para=np.random.binomial(n,p1,size=size)
hileli_para=np.random.binomial(n,p2,size=size)

p_tura_normal_para=pd.DataFrame([np.equal(normal_para,i).mean() for i in range (n)])
p_tura_hileli_para=pd.DataFrame([np.equal(hileli_para,i).mean() for i in range (n)])

plt.plot(list(range(n)),p_tura_normal_para , color="yellow", marker="o")
plt.xlabel("tura sayısı", fontsize=14)
plt.ylabel("olasılık" , fontsize=14)

plt.plot(list(range(n)),p_tura_hileli_para , color="purple", marker="o")
plt.xlabel("hatalı para tura sayısı", fontsize=14)
plt.ylabel("olasılık" , fontsize=14)
# Out:
# Text(0, 0.5, 'olasılık')
